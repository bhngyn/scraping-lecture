# %% [markdown]
# # Scraping dynamic web sites with Selenium
#
# [Last week's lesson](../pt1/scraping_lecture.ipynb) involved scraping a static site, or a site that is rendered up front in HTML. Today, we'll look at how to scrape sites that change when you load or interact with the page, sometimes without the URL changing.
#
# [Selenium](https://www.selenium.dev/documentation/) was created to "automate browsers." The major use case for software like Selenium is to automate testing browser-based apps. But journalists can use software like Selenium to scrape dynamic websites.
#
# For today's lesson, we're going to scrape all the public hearings in Alameda County courts on a given day.

# %%
import pandas as pd
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm

from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.by import By

import time
import math

# %% [markdown]
# ## Open your automated browser
#
# Earlier we installed `chromedriver` using `brew`. Below, we tell Selenium to use Chrome as our automated browser.

# %%
# initiate webdriver
driver = webdriver.Chrome()

# some people like to call this variable `browser` — call it whatever you like!

# %% [markdown]
# ## Open the website

# %%
# Navigate to a URL
driver.get('https://publicrecords.alameda.courts.ca.gov/CalendarSearch/')

# %% [markdown]
# ## Find the inputs you want to interact with
#
# In last week's lecture, we used Beautiful Soup to find elements on a page. Because we want to interact with elements within Selenium's automated browser, we need to use Selenium to find elements.
#
# Tips:
# - If you want to interact with the page, use selenium
# - If you want to read or parse complex HTML, use bs4
#
# You'll use `By` to indicate how the browser will pinpoint your element. These are the [different options for `By`](https://www.selenium.dev/selenium/docs/api/py/webdriver/selenium.webdriver.common.by.html):
#
# - `CLASS_NAME`
# - `CSS_SELECTOR` (e.g. a pseudo-element)
# - `ID`
# - `LINK_TEXT` (the text inside <a> tags)
# - `NAME`
# - `PARTIAL_LINK_TEXT` (the text inside <a> tags)
# - `TAG_NAME`
# - `XPATH` (when the element doesn't have a unique identifer, you can still pinpoint with this method; Chrome has a cool way to grab the xpath of an item in Developer Tools)
#
# Luckily, the date fields have IDs, so we can select them this way:

# %%
hearing_date_from = driver.find_element(By.ID, 'FeaturedContent_txtFromdt')
hearing_date_to   = driver.find_element(By.ID, 'FeaturedContent_txtTodt')

# %% [markdown]
# You can use `type()` to find out whether a variable is a selenium object or a bs4 object.

# %%
type(hearing_date_from)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %% [markdown]
# ## Input dates into the dropdowns
#
# Use selenium's `send_keys()` method to input text into the date dropdowns.

# %%
hearing_date_from.send_keys('12/06/2021')
hearing_date_to.send_keys('12/06/2021')

# %% [markdown]
# ## "Click" on the submit button
#
# First, you'll have to find the element by its `id` value, then `click()` on it.

# %%
submit_button = driver.find_element(By.ID, 'FeaturedContent_btFind')

# %%
submit_button.click()

# %% [markdown]
# Below, I'm telling the computer to wait 5 seconds before executing the next line of code. That way the browser can finish loading the page before continuing with the code. That's crucial if I end up restarting this notebook kernel and running all cells at once. We want the browser to finish loading the page because some elements might not exist until the element exists.

# %%
time.sleep(5)

# %% [markdown]
# There are better ways to wait for elements on a page. Check out the documentation to read more about [WebDriverWait()](https://selenium-python.readthedocs.io/waits.html).

# %% [markdown]
# ## "Select" more rows to view
#
# When you  get your search results, the courts show only 10 rows at a time. It'll be faster to scrape all the results if you can show the max amount of rows at a time (which is 50).

# %%
displayed_rows_dropdown = Select(driver.find_element(By.NAME, 'ctl00$MainContent$gvResult$ctl13$ctl13'))

# %%
displayed_rows_dropdown.select_by_visible_text('50')

# %% [markdown]
# ## Get the count of results so you know how many pages you have to scrape
#
# Even though I'm parsing HTML below, I'm using Selenium instead of Beautiful Soup. I'm doing this because I haven't called Beautiful Soup yet and Selenium is capable of parsing.

# %%
records_count_container = driver.find_element(By.ID, 'MainContent_lbCnt')
records_count = records_count_container.text.split()
records_count = records_count[-1]
records_count = int(records_count)
records_count
# Out:
# 1395

# %%
pages_to_check = math.ceil(records_count/50)
pages_to_check
# Out:
# 28

# %% [markdown]
# ## Figure out how to loop through the pages

# %%
# find the "Next" link — it looks like ">"
next_button = driver.find_element(By.LINK_TEXT, '>')
next_button.click()

# %% [markdown]
# The below code is commented out because I don't want you to run it yet. But, you can see how one could flip through all the pages of this site.

# %%
# for n in range(pages_to_check):
#     next_button = driver.find_element(By.LINK_TEXT, '>')
#     next_button.click()
    
#     # wait 2 seconds
#     time.sleep(2)

# %% [markdown]
# You can manually get back to the first page by going to the "automated" browser and clicking "1".

# %% [markdown]
# ## Parse the first page of results with Beautiful Soup
#
# Now I'm going to switch to using Beautiful Soup because it's the best program to parse through a lot of HTML.

# %% [markdown]
# ### Get the table by its `id`

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
table = soup.find(id='MainContent_gvResult')

# %%
# table

# %% [markdown]
# Each row of this table is a unique something. I'm not sure what that something is. It might not be a unique case. It might be something else. I'm not going to assume. Anyway, I'd like to transfer this table into a pandas dataframe.
#
# ### Create your blank dataframe

# %%
hearings = pd.DataFrame(
    columns=[
        'Serial No.',
        'Name',
        'Case #',
        'PFN',
        'CEN',
        'Dept#',
        'Hearing Date',
        'Hearing Time',
        'Hearing Type',
        'Case Type',
        'Defense Atty',
        'DA'
    ])

# %% [markdown]
# ### Parse the table and put the data into a dataframe
#
# Let's go over each section below manually before running.

# %%
# create a simple `page_data` list to store the page data before we make a pandas dataframe
page_data = []
rows = table.find_all('tr')

# we haven't used enumerate() yet but basically that just allows you to index an iterable
for i, row in enumerate(rows):

    # we can skip the first row because that's the header row
    # we can also skip any row greater than index 50 because that has the page numbers
    if (i > 0) and (i <= 50):
    
        # `cells` will get and index all the cells within a row
        cells = row.find_all('td')
        page_data.append({
            'Serial No.' : cells[0].text.strip(),
            'Name' : cells[1].text.strip(), 
            'Case #' : cells[2].text.strip(), 
            'PFN' : cells[3].text.strip(), 
            'CEN' : cells[4].text.strip(), 
            'Dept#' : cells[5].text.strip(), 
            'Hearing Date' : cells[6].text.strip(), 
            'Hearing Time' : cells[7].text.strip(), 
            'Hearing Type' : cells[8].text.strip(), 
            'Case Type' : cells[9].text.strip(), 
            'Defense Atty' : cells[10].text.strip(), 
            'DA' : cells[11].text.strip()
        })
        
# create a dataframe with `page_data`
page_hearing = pd.DataFrame(page_data)

# %% [markdown]
# ## Append `page_hearing` dataframe to main `hearings` dataframe

# %%
hearings = hearings.append(page_hearing).reset_index(drop=True)

# %% [markdown]
# ## View dataframe

# %%
hearings
# Out:
#    Serial No.                          Name         Case #     PFN      CEN  \
# 0           1            FOSTER, JIMMIE LEE         167627  AYO984  1340030
# 1           2                THOMAS, MARKEL         410407  BGN192  8324445
# 2           3                  MOORE, MARIA  18-CR-019696B  BMD439  8418630
# 3           4               SALVANT, MARVEL  18-CR-019696A  BMD440  8418631
# 4           5      STANDLEY, CURTIS RICHARD   17-CR-027648  BGT167  7831868
# 5           6      STANDLEY, CURTIS RICHARD        178554A  BGT167  6294134
# 6           7          WATSON, WILL ANTHONY   17-CR-003246  BLJ096  7803487
# 7           8           CASTRO, FREDY AMAYA   20-CR-011202  BEU230  0503818
# 8           9     CRAWFORD, LAMAR LEEJORDAN   20-CR-010100  DTC648  0501382
# 9          10        ELLIS, ANTOINE MARQUIS   18-CR-019861  BCV669  8418862
# 10         11           FRAZIER, CALLIE MAY   19-CR-001998  BLP859  7832161
# 11         12   GUTIERREZVILLANU, FRANCISCO   19-CR-015180  BML841  9415851
# 12         13   GUTIERREZVILLANU, FRANCISCO   20-CR-001606  BML841  0482912
# 13         14      HILLS, CHARLES JEFFERSON   19-CR-009868  ATO453  9404176
# 14         15      HILLS, CHARLES JEFFERSON   19-CR-009868  DSS968  9404176
# 15         16      HILLS, CHARLES JEFFERSON   19-CR-009868  DSX089  9404176
# 16         17            HUBER, JOHN EDWARD   18-CR-005746  AOW685  8385362
# 17         18           LOVELL, SHANE ALLEN   19-CR-014692  BBI474  9414549
# 18         19           LOVELL, SHANE ALLEN   21-CR-004040  BBI474  1369830
# 19         20  MASENGALE, ANDREW TYLERLUCAS   20-CR-001117  BMO446  9426791
# 20         21                    MORA, JUAN   18-CR-002825  BCH633  8379737
# 21         22        TERRIQUEZ, JOSE LEONOR   18-CR-016037  BMB051  8409043
# 22         23        TERRIQUEZ, JOSE LEONOR  19-CR-007046C  BMB051  9406078
# 23         24        TERRIQUEZ, JOSE LEONOR  19-CR-007046C  BMB051  9406078
# 24         25       THOMPSON, MALCOLM LAMAR   21-CR-000061  BGR293  1362397
# 25         26       THOMPSON, MALCOLM LAMAR   21-CR-000061  DSR429  1362397
# 26         27       THOMPSON, MALCOLM LAMAR   21-CR-000061  DTD693  1362397
# 27         28        THOMPSON, MALCOM LAMAR   20-CR-013014  BGR293  0508005
# 28         29        THOMPSON, MALCOM LAMAR   20-CR-013014  DSR429  0508005
# 29         30        THOMPSON, MALCOM LAMAR   20-CR-013014  DTD693  0508005
# 30         31               TRAN, LINH DINH   21-CR-008302  BKQ486  6282775
# 31         32           VALDEZ, ORO ALBERTO   21-CR-003182  BKC177  1368290
# 32         33              SMITH, TERRICK L   21-CR-010013  BBE678  1383700
# 33         34              SMITH, TERRICK L   21-CR-001018  BBE678  1364155
# 34         35              SMITH, TERRICK L   20-CR-015014  BBE678  0511948
# 35         36             VANBUREN, BERNARD  20-CR-011859D  BMT480  0505336
# 36         37   GARCIACARILLO, JUAN ANTONIO   20-CR-011269  BMT170  0504005
# 37         38          AGABAO, RONALD JASON   21-CR-010877  AXY813  1385710
# 38         39          AGABAO, RONALD JASON   21-CR-011559  AXY813  1387012
# 39         40                ALVARADO, JOHN   21-CR-010665  BMQ903  1385181
# 40         41                ALVARADO, JOHN   20-CR-010335  BMQ903  0501897
# 41         42       BARROW, TRAVIS CHISSELL   21-CR-006464  BHA163  1375509
# 42         43      BRANDON, URSELL LAVAUGHN         176594  AQH965  5300397
# 43         44       BRITTON, RECHARD TRUMAN   21-CR-001071  BKW082  1363950
# 44         45          BROWN, RAYMON SHAKUR   21-CR-004595  BMW228  1364126
# 45         46              BRUMFIELD, MIKEL   19-CR-005192  BAT913  9393384
# 46         47         BRUMFIELD, MIKEL ALAN   21-CR-011824  BAT913  1387870
# 47         48           CARIAS, LUDYN PEREZ   20-CR-015373  BMH221  0513118
# 48         49         CARLISLE, KETURAH LEE   20-CR-011053  AWV809  0503499
# 49         50           CHARLES RAY JACKSON   19-CR-009598  BMG579  9403256
#
#    Dept# Hearing Date Hearing Time                               Hearing Type  \
# 0          12/06/2021       9:00AM                                    Hearing
# 1          12/06/2021       9:00AM                                    Hearing
# 2    002   12/06/2021       8:30AM                         Further Jury Trial
# 3    002   12/06/2021       8:30AM                         Further Jury Trial
# 4    003   12/06/2021       8:30AM                         Further Jury Trial
# 5    003   12/06/2021       8:30AM      Hearing After Revocation of Probation
# 6    005   12/06/2021       8:30AM                         Further Jury Trial
# 7    006   12/06/2021       8:30AM                               Bail Hearing
# 8    006   12/06/2021       8:30AM                           Bail Bond Motion
# 9    006   12/06/2021       8:30AM                   Motion pursuant to 995PC
# 10   006   12/06/2021       8:30AM                                     Motion
# 11   006   12/06/2021       8:30AM                           Bail Bond Motion
# 12   006   12/06/2021       8:30AM                           Bail Bond Motion
# 13   006   12/06/2021       8:30AM                                     Motion
# 14   006   12/06/2021       8:30AM                                     Motion
# 15   006   12/06/2021       8:30AM                                     Motion
# 16   006   12/06/2021       8:30AM                           Bail Bond Motion
# 17   006   12/06/2021       8:30AM                           Bail Bond Motion
# 18   006   12/06/2021       8:30AM                           Bail Bond Motion
# 19   006   12/06/2021       8:30AM                           Bail Bond Motion
# 20   006   12/06/2021       8:30AM                           Bail Bond Motion
# 21   006   12/06/2021       8:30AM  Set Hearing After Revocation of Probation
# 22   006   12/06/2021       8:30AM                                     Motion
# 23   006   12/06/2021       8:30AM                   Motion pursuant to 995PC
# 24   006   12/06/2021       8:30AM                      Motion to Consolidate
# 25   006   12/06/2021       8:30AM                      Motion to Consolidate
# 26   006   12/06/2021       8:30AM                      Motion to Consolidate
# 27   006   12/06/2021       8:30AM                      Motion to Consolidate
# 28   006   12/06/2021       8:30AM                      Motion to Consolidate
# 29   006   12/06/2021       8:30AM                      Motion to Consolidate
# 30   006   12/06/2021       8:30AM                          Motion to Dismiss
# 31   006   12/06/2021       8:30AM                               Bail Hearing
# 32   007   12/06/2021       8:30AM                         Further Jury Trial
# 33   007   12/06/2021       8:30AM  Set Hearing After Revocation of Probation
# 34   007   12/06/2021       8:30AM  Set Hearing After Revocation of Probation
# 35   007   12/06/2021       8:30AM                        Issue Bench Warrant
# 36   009   12/06/2021       8:30AM                        Preliminary Hearing
# 37   011   12/06/2021       8:30AM                        Report and Sentence
# 38   011   12/06/2021       8:30AM                          Motion to Dismiss
# 39   011   12/06/2021       8:30AM                        Report and Sentence
# 40   011   12/06/2021       8:30AM                          Motion to Dismiss
# 41   011   12/06/2021       8:30AM  Set Hearing After Revocation of Probation
# 42   011   12/06/2021       8:30AM                        Report and Sentence
# 43   011   12/06/2021       8:30AM  Set Hearing After Revocation of Probation
# 44   011   12/06/2021       8:30AM                        Report and Sentence
# 45   011   12/06/2021       8:30AM                  Sentence After Revocation
# 46   011   12/06/2021       8:30AM                        Report and Sentence
# 47   011   12/06/2021       8:30AM                  Sentence After Revocation
# 48   011   12/06/2021       8:30AM  Set Hearing After Revocation of Probation
# 49   011   12/06/2021       8:30AM                  Sentence After Revocation
#
#                   Case Type                    Defense Atty  \
# 0                    Felony
# 1   Misdemeanor/Infractions
# 2                    Felony       Darryl Antonio Stallworth
# 3                    Felony           Christina Marie Moore
# 4                    Felony            Anne Catherine Beles
# 5                    Felony              David Emmett Klaus
# 6                    Felony           Hugo Ernesto Castillo
# 7                    Felony           Madeline Maria Zepeda
# 8                    Felony
# 9                    Felony             Ernesto H. Castillo
# 10                   Felony         Anthony Michael Blalock
# 11                   Felony             Kendra Nicole Clark
# 12  Misdemeanor/Infractions             Kendra Nicole Clark
# 13  Misdemeanor/Infractions         Michael Simon Wasserman
# 14  Misdemeanor/Infractions         Michael Simon Wasserman
# 15  Misdemeanor/Infractions         Michael Simon Wasserman
# 16                   Felony     Christopher Phillip Dobbins
# 17                   Felony             Willie Javon Mincey
# 18                   Felony             Willie Javon Mincey
# 19  Misdemeanor/Infractions                Hien Ngoc Nguyen
# 20                   Felony             Ernesto H. Castillo
# 21                   Felony            David Jonathan Cohen
# 22                   Felony            David Jonathan Cohen
# 23                   Felony            David Jonathan Cohen
# 24  Misdemeanor/Infractions                      Bao A Doan
# 25  Misdemeanor/Infractions                      Bao A Doan
# 26  Misdemeanor/Infractions                      Bao A Doan
# 27                   Felony                      Bao A Doan
# 28                   Felony                      Bao A Doan
# 29                   Felony                      Bao A Doan
# 30                   Felony               Anna Y Kashtanova
# 31                   Felony             Ernesto H. Castillo
# 32                   Felony                  Loren Williams
# 33                   Felony             Willie Javon Mincey
# 34                   Felony                  Loren Williams
# 35                   Felony            David Jonathan Cohen
# 36                   Felony  Camila Rosario Nieves-McCarthy
# 37                   Felony  Joseph Irving Goldstein-Breyer
# 38  Misdemeanor/Infractions  Joseph Irving Goldstein-Breyer
# 39                   Felony                  Kathleen Ryals
# 40                   Felony             Desiree Adell Woods
# 41                   Felony  Joseph Irving Goldstein-Breyer
# 42                   Felony                 Tiffany M Danao
# 43                   Felony                  Kathleen Ryals
# 44                   Felony             Michael Wohlstadter
# 45                   Felony              Alexander J Thayer
# 46                   Felony              Alexander J Thayer
# 47                   Felony        Kristina Lynn Kliszewski
# 48                   Felony          Daniel Eugene Duvernay
# 49                   Parole           Emily Elizabeth Klein
#
#                              DA
# 0
# 1
# 2           Alexander Hernandez
# 3           Alexander Hernandez
# 4            Angelina Lisa Clay
# 5         John Norman Creighton
# 6   Christopher David Cavagnaro
# 7         William Matthew Layne
# 8         William Matthew Layne
# 9       Charles Francis Bisesto
# 10              Robert L. Mohen
# 11           John Joseph Mifsud
# 12     William Lawrence Boselli
# 13           John Joseph Mifsud
# 14           John Joseph Mifsud
# 15           John Joseph Mifsud
# 16           Robert Andrew Ross
# 17     Margaret Lillian Calonge
# 18         Kevin Tsuyoshi Ikuma
# 19         Georgia Huang Santos
# 20          Connie Rae Campbell
# 21                  Keydon Levy
# 22             Josefa Ada James
# 23             Josefa Ada James
# 24     Lauren Tierney Hashimoto
# 25     Lauren Tierney Hashimoto
# 26     Lauren Tierney Hashimoto
# 27  Veronica Amaya Rios Reddick
# 28  Veronica Amaya Rios Reddick
# 29  Veronica Amaya Rios Reddick
# 30      Brooke Danielle Perkins
# 31     Lauren Tierney Hashimoto
# 32          Camille Lynne Ching
# 33       Ashley Dodson Carvolth
# 34  Veronica Amaya Rios Reddick
# 35                  James Logan
# 36  Veronica Amaya Rios Reddick
# 37       Ashley Dodson Carvolth
# 38                Raul Jacobson
# 39       Ashley Dodson Carvolth
# 40       Christopher Roger Chin
# 41         David Cavanaugh Cook
# 42               Erin Kingsbury
# 43       Ashley Dodson Carvolth
# 44           Robert Andrew Ross
# 45             Josefa Ada James
# 46          Camille Lynne Ching
# 47  Veronica Amaya Rios Reddick
# 48       Ashley Dodson Carvolth
# 49     Margaret Lillian Calonge

# %%
# for n in range(pages_to_check):
#     next_button = driver.find_element(By.LINK_TEXT, '>')
#     next_button.click()
#     soup = BeautifulSoup(driver.page_source, 'html.parser')
#     table = soup.find(id='MainContent_gvResult')
#     time.sleep(2)

# %% [markdown]
# ## Addenda
#
# If I want to search for another date, I can stay on the same page and "clear" the date fields. Then I send send new dates.

# %%
hearing_date_from.clear()
hearing_date_to.clear()

hearing_date_from.send_keys('12/07/2021')
hearing_date_to.send_keys('12/07/2021')

# %% [markdown]
# Once you're done using the automated browser, you can close it manually or run the following:

# %%
driver.close()

# %% [markdown]
# ## Classwork
#
# I'd like you to figure out how to loop through all the pages and collect all the information.
